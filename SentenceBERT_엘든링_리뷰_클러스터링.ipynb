# %% [markdown]
# <a href="https://colab.research.google.com/github/A1R-3112/SentenceBERT_with_Eldenring_Review/blob/main/SentenceBERT_%EC%97%98%EB%93%A0%EB%A7%81_%EB%A6%AC%EB%B7%B0_%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SentenceBERT 한국어 문장 클러스터링

# %% [markdown]
# ## GPU 사용 확인
#
# 메뉴 - 런타임 - 런타임 유형 변경 - 하드웨어 가속기 - GPU 확인

# %%
# !nvidia-smi
# Out:
# Thu Dec 15 02:47:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    29W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Sentence Transformers 패키지 설치

# %%
# !pip install -q -U sentence-transformers
# Out:
#      |████████████████████████████████| 85 kB 2.8 MB/s
#      |████████████████████████████████| 5.8 MB 68.5 MB/s
#      |████████████████████████████████| 1.3 MB 51.8 MB/s
#      |████████████████████████████████| 182 kB 27.1 MB/s
#      |████████████████████████████████| 7.6 MB 48.6 MB/s
#   Building wheel for sentence-transformers (setup.py) ... done

# %% [markdown]
# ## 문장 임베딩
#
# 한국어 문장 -> 숫자 벡터로 변환하기
#
# https://huggingface.co/jhgan/ko-sroberta-multitask

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('jhgan/ko-sroberta-multitask')

sentences = ["안녕하세요?", "한국어 문장 임베딩을 위한 버트 모델입니다."]
embeddings = model.encode(sentences)

print(embeddings)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/744 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/931 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/302 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/495k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/585 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# [[-0.37510476 -0.77338415  0.5927711  ...  0.57923514  0.3268347
#   -0.65089625]
#  [-0.09361722 -0.18191545 -0.19230829 ... -0.03165793  0.3041255
#   -0.26793614]]

# %% [markdown]
# ## 클러스터링 샘플 코드

# %%
from sklearn.cluster import KMeans

# Corpus with example sentences
sentences = ['한 남자가 음식을 먹는다.',
          '한 남자가 빵 한 조각을 먹는다.',
          '그 여자가 아이를 돌본다.',
          '한 남자가 말을 탄다.',
          '한 여자가 바이올린을 연주한다.',
          '두 남자가 수레를 숲 속으로 밀었다.',
          '한 남자가 담으로 싸인 땅에서 백마를 타고 있다.',
          '원숭이 한 마리가 드럼을 연주한다.',
          '치타 한 마리가 먹이 뒤에서 달리고 있다.',
          '한 남자가 파스타를 먹는다.',
          '고릴라 의상을 입은 누군가가 드럼을 연주하고 있다.',
          '치타가 들판을 가로 질러 먹이를 쫓는다.']

embeddings = model.encode(sentences)

# Then, we perform k-means clustering using sklearn:
num_clusters = 5
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = [[] for i in range(num_clusters)]
for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(sentences[sentence_id])

for i, cluster in enumerate(clustered_sentences):
    print("Cluster ", i+1)
    print(cluster)
    print("")
# Out:
# Cluster  1
# ['한 여자가 바이올린을 연주한다.', '원숭이 한 마리가 드럼을 연주한다.', '고릴라 의상을 입은 누군가가 드럼을 연주하고 있다.']
#
# Cluster  2
# ['치타 한 마리가 먹이 뒤에서 달리고 있다.', '치타가 들판을 가로 질러 먹이를 쫓는다.']
#
# Cluster  3
# ['한 남자가 음식을 먹는다.', '한 남자가 빵 한 조각을 먹는다.', '한 남자가 파스타를 먹는다.']
#
# Cluster  4
# ['한 남자가 말을 탄다.', '두 남자가 수레를 숲 속으로 밀었다.', '한 남자가 담으로 싸인 땅에서 백마를 타고 있다.']
#
# Cluster  5
# ['그 여자가 아이를 돌본다.']

# %% [markdown]
# # 스팀 리뷰 크롤링

# %% [markdown]
# ### 미리 크롤링한거 다운로드
#
# '엘든링 리뷰 임베딩'으로 이동
#
# https://github.com/kairess/KoSentenceBERT-SKT/raw/main/eldenring_stream_reviews_ko.csv

# %%
import pandas as pd

df = pd.read_csv('https://github.com/kairess/KoSentenceBERT-SKT/raw/main/eldenring_stream_reviews_ko.csv')

df.head()
# Out:
#    recommendationid                                             author  \
# 0         111342915  {'steamid': '76561198065764106', 'num_games_ow...
# 1         111348309  {'steamid': '76561198139607001', 'num_games_ow...
# 2         111071449  {'steamid': '76561198032918620', 'num_games_ow...
# 3         111338648  {'steamid': '76561198411570102', 'num_games_ow...
# 4         111350106  {'steamid': '76561198045823651', 'num_games_ow...
#
#   language                                             review  \
# 0  koreana                                           피했다고 씨발아
# 1  koreana                          이 너머 점프 유효하다 이 앞 거짓말쟁이 있다
# 2  koreana  장점은 갓겜 단점은 개적화 제어판에서 쉐이더 캐쉬 무제한 설정 관리 프로그램 설정 ...
# 3  koreana                   트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔
# 4  koreana                                      화가나도 사랑한다 씹새야
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1646182946         1646907680      True      1196          878
# 1         1646189703         1646189893      True       385          211
# 2         1645880172         1645880397      True       387            3
# 3         1646177519         1646177519      True       240          265
# 4         1646191684         1646191684      True       140           45
#
#    weighted_vote_score  comment_count  steam_purchase  received_for_free  \
# 0             0.966845              0            True              False
# 1             0.954688              0            True              False
# 2             0.924138              0            True              False
# 3             0.904640              3            True              False
# 4             0.868988              0            True              False
#
#    written_during_early_access
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %% [markdown]
# ### [옵션2] 직접 크롤링하기
#
# - 엘든링 리뷰: https://steamcommunity.com/app/1245620/reviews/?p=1&filterLanguage=koreana&browsefilter=toprated
# - Reference: https://github.com/arditoibryan/datasets/blob/main/220226_steam/get_reviews.ipynb

# %%
import requests
import time

# %%
def get_reviews(appid, params={'json':1}):
        url = 'https://store.steampowered.com/appreviews/'
        response = requests.get(url=url+str(appid), params=params, headers={'User-Agent': 'Mozilla/5.0'})
        return response.json()

def get_n_reviews(appid, n=100):
    reviews = []
    cursor = '*'
    params = {
        'json' : 1,
        'filter' : 'all',
        'language' : 'koreana',
        'day_range' : 9223372036854775807,
        'review_type' : 'all',
        'purchase_type' : 'all'
    }

    while n > 0:
        time.sleep(2)
        params['cursor'] = cursor.encode()
        params['num_per_page'] = min(100, n)
        n -= 100

        response = get_reviews(appid, params)
        cursor = response['cursor']
        reviews += response['reviews']

        if len(response['reviews']) < 100: break

    return reviews

# %%
reviews = get_n_reviews(1245620, 10000)

reviews[:5]
# Out:
# [{'author': {'last_played': 1647652169,
#    'num_games_owned': 94,
#    'num_reviews': 8,
#    'playtime_at_review': 8099,
#    'playtime_forever': 9434,
#    'playtime_last_two_weeks': 3237,
#    'steamid': '76561198065764106'},
#   'comment_count': 0,
#   'language': 'koreana',
#   'received_for_free': False,
#   'recommendationid': '111342915',
#   'review': '피했다고 씨발아',
#   'steam_purchase': True,
#   'timestamp_created': 1646182946,
#   'timestamp_updated': 1646907680,
#   'voted_up': True,
#   'votes_funny': 878,
#   'votes_up': 1196,
#   'weighted_vote_score': '0.966844797134399414',
#   'written_during_early_access': False},
#  {'author': {'last_played': 1647612501,
#    'num_games_owned': 168,
#    'num_reviews': 57,
#    'playtime_at_review': 612,
#    'playtime_forever': 2044,
#    'playtime_last_two_weeks': 1211,
#    'steamid': '76561198139607001'},
#   'comment_count': 0,
#   'language': 'koreana',
#   'received_for_free': False,
#   'recommendationid': '111348309',
#   'review': '이 너머, 점프 유효하다\n\n이 앞, 거짓말쟁이 있다',
#   'steam_purchase': True,
#   'timestamp_created': 1646189703,
#   'timestamp_updated': 1646189893,
#   'voted_up': True,
#   'votes_funny': 211,
#   'votes_up': 385,
#   'weighted_vote_score': '0.954687893390655518',
#   'written_during_early_access': False},
#  {'author': {'last_played': 1647658884,
#    'num_games_owned': 1954,
#    'num_reviews': 66,
#    'playtime_at_review': 636,
#    'playtime_forever': 8751,
#    'playtime_last_two_weeks': 5258,
#    'steamid': '76561198032918620'},
#   'comment_count': 0,
#   'language': 'koreana',
#   'received_for_free': False,
#   'recommendationid': '111071449',
#   'review': '장점은 갓겜\n\n단점은 개적화;;;\n\nNVIDIA 제어판에서 쉐이더 캐쉬 => 무제한\n3D 설정 관리 => 프로그램 설정 => 엘든링 추가 => 전원 관리 모드를 "최고 성능 선호" \n카메라 조작중 스터터링 증상 모두 사라짐..',
#   'steam_purchase': True,
#   'timestamp_created': 1645880172,
#   'timestamp_updated': 1645880397,
#   'voted_up': True,
#   'votes_funny': 3,
#   'votes_up': 387,
#   'weighted_vote_score': '0.924138486385345459',
#   'written_during_early_access': False},
#  {'author': {'last_played': 1646808371,
#    'num_games_owned': 11,
#    'num_reviews': 1,
#    'playtime_at_review': 341,
#    'playtime_forever': 962,
#    'playtime_last_two_weeks': 452,
#    'steamid': '76561198411570102'},
#   'comment_count': 3,
#   'language': 'koreana',
#   'received_for_free': False,
#   'recommendationid': '111338648',
#   'review': '트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'steam_purchase': True,
#   'timestamp_created': 1646177519,
#   'timestamp_updated': 1646177519,
#   'voted_up': True,
#   'votes_funny': 265,
#   'votes_up': 240,
#   'weighted_vote_score': '0.904639720916748047',
#   'written_during_early_access': False},
#  {'author': {'last_played': 1647634392,
#    'num_games_owned': 154,
#    'num_reviews': 3,
#    'playtime_at_review': 4560,
#    'playtime_forever': 7712,
#    'playtime_last_two_weeks': 2690,
#    'steamid': '76561198045823651'},
#   'comment_count': 0,
#   'language': 'koreana',
#   'received_for_free': False,
#   'recommendationid': '111350106',
#   'review': '화가나도 사랑한다 씹새야',
#   'steam_purchase': True,
#   'timestamp_created': 1646191684,
#   'timestamp_updated': 1646191684,
#   'voted_up': True,
#   'votes_funny': 45,
#   'votes_up': 140,
#   'weighted_vote_score': '0.868988394737243652',
#   'written_during_early_access': False}]

# %%
import pandas as pd

df = pd.DataFrame.from_dict(reviews)

df.head()
# Out:
#   recommendationid                                             author  \
# 0        111342915  {'steamid': '76561198065764106', 'num_games_ow...
# 1        111348309  {'steamid': '76561198139607001', 'num_games_ow...
# 2        111071449  {'steamid': '76561198032918620', 'num_games_ow...
# 3        111338648  {'steamid': '76561198411570102', 'num_games_ow...
# 4        111350106  {'steamid': '76561198045823651', 'num_games_ow...
#
#   language                                             review  \
# 0  koreana                                           피했다고 씨발아
# 1  koreana                     이 너머, 점프 유효하다\n\n이 앞, 거짓말쟁이 있다
# 2  koreana  장점은 갓겜\n\n단점은 개적화;;;\n\nNVIDIA 제어판에서 쉐이더 캐쉬 =>...
# 3  koreana       트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 4  koreana                                      화가나도 사랑한다 씹새야
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1646182946         1646907680      True      1196          878
# 1         1646189703         1646189893      True       385          211
# 2         1645880172         1645880397      True       387            3
# 3         1646177519         1646177519      True       240          265
# 4         1646191684         1646191684      True       140           45
#
#     weighted_vote_score  comment_count  steam_purchase  received_for_free  \
# 0  0.966844797134399414              0            True              False
# 1  0.954687893390655518              0            True              False
# 2  0.924138486385345459              0            True              False
# 3  0.904639720916748047              3            True              False
# 4  0.868988394737243652              0            True              False
#
#    written_during_early_access
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %% [markdown]
# ## 전처리
#
# - 한글이 아닌 글자 제거
# - 작은따옴표 제거
# - 연속된 공백 제거
# - 좌우 공백 제거
# - 최대 글자 255자

# %%
df['review'] = df['review'] \
  .replace(r'[^가-힣 ]', ' ', regex=True) \
  .replace("'", '') \
  .replace(r'\s+', ' ', regex=True) \
  .str.strip() \
  .str[:255]

df.head()
# Out:
#    recommendationid                                             author  \
# 0         111342915  {'steamid': '76561198065764106', 'num_games_ow...
# 1         111348309  {'steamid': '76561198139607001', 'num_games_ow...
# 2         111071449  {'steamid': '76561198032918620', 'num_games_ow...
# 3         111338648  {'steamid': '76561198411570102', 'num_games_ow...
# 4         111350106  {'steamid': '76561198045823651', 'num_games_ow...
#
#   language                                             review  \
# 0  koreana                                           피했다고 씨발아
# 1  koreana                          이 너머 점프 유효하다 이 앞 거짓말쟁이 있다
# 2  koreana  장점은 갓겜 단점은 개적화 제어판에서 쉐이더 캐쉬 무제한 설정 관리 프로그램 설정 ...
# 3  koreana                   트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔
# 4  koreana                                      화가나도 사랑한다 씹새야
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1646182946         1646907680      True      1196          878
# 1         1646189703         1646189893      True       385          211
# 2         1645880172         1645880397      True       387            3
# 3         1646177519         1646177519      True       240          265
# 4         1646191684         1646191684      True       140           45
#
#    weighted_vote_score  comment_count  steam_purchase  received_for_free  \
# 0             0.966845              0            True              False
# 1             0.954688              0            True              False
# 2             0.924138              0            True              False
# 3             0.904640              3            True              False
# 4             0.868988              0            True              False
#
#    written_during_early_access
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %% [markdown]
# ## 전처리2
#
# 아무것도 안써있는 리뷰 제거

# %%
df = df[df['review'].str.strip().astype(bool)]

len(df)
# Out:
# 8242

# %% [markdown]
# 마지막으로 확인

# %%
df['review'].values.tolist()[:5]
# Out:
# ['피했다고 씨발아',
#  '이 너머 점프 유효하다 이 앞 거짓말쟁이 있다',
#  '장점은 갓겜 단점은 개적화 제어판에서 쉐이더 캐쉬 무제한 설정 관리 프로그램 설정 엘든링 추가 전원 관리 모드를 최고 성능 선호 카메라 조작중 스터터링 증상 모두 사라짐',
#  '트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔',
#  '화가나도 사랑한다 씹새야']

# %% [markdown]
# ## CSV 파일로 저장

# %%
df.to_csv('eldenring_stream_reviews_ko.csv', index=False)

# %% [markdown]
# ## 엘든링 리뷰 임베딩

# %%
corpus = df['review'].values.tolist()

embeddings = model.encode(corpus)

embeddings[:5]
# Out:
# array([[-0.22529401, -0.4175359 ,  0.61303973, ..., -0.10349669,
#         -0.7012687 , -0.56171364],
#        [-0.90645707,  0.02967468,  1.0217901 , ...,  0.22810629,
#         -0.06951927,  0.10106487],
#        [-0.19821462,  0.33884323,  0.4552724 , ...,  0.09432774,
#          0.07606549,  0.00539316],
#        [-0.32800043,  0.11018946,  0.81971127, ..., -0.08382823,
#         -0.6934303 , -0.56812966],
#        [-0.18077008,  0.00652812,  0.01430991, ...,  0.27408373,
#         -0.25302646, -0.75834996]], dtype=float32)

# %% [markdown]
# ## k=5 클러스터링

# %%
num_clusters = 5
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = [[] for i in range(num_clusters)]
for sentence_id, cluster_id in enumerate(cluster_assignment):
    clustered_sentences[cluster_id].append(corpus[sentence_id])

for i, cluster in enumerate(clustered_sentences):
    print('Cluster %d (%d)' % (i+1, len(cluster)))
    print(cluster)
    print('')
# Out:
# Cluster 1 (2771)
# ['피했다고 씨발아', '이 너머 점프 유효하다 이 앞 거짓말쟁이 있다', '트리가드 얘때문에 빡종하고 롤키니깐 헤카림 나와서 롤도 끔', '화가나도 사랑한다 씹새야', '시발 시발 개시발 거리면서도 하게되는 내 모습을 보니 빛바랜 자 최적화 지능인듯', '목표는 구멍 그리고 씨앗 바쳐라', '오늘도 나는 그들에게 메세지를 남긴다 이 너머 숨겨진 길 있다', '피씨는 조금 더 기다렸다가 구입하길 추천드립니다', '그럴 자격 없다 오오 그럴 자격없다', '나는 프레임드랍 조금있고 프리징현상 없어서 개추', '씨발 렉 멈춰', '확실히 엘든링을 사고 나서 내 인생이 달라졌다 원래는 고딩때 일진 눈도 못마주치고 쓰레기 아무데나 버리고 침 찍찍 뱉고 했는데 엘든링 빛바랜 자 오너가 되고나니깐 품위유지 할려고 스스로 노력할려고한다 방금도 길바닥에 포스틱봉지 버려져있길래 주워서 쓰레기통에 버리고왔다 학생때는 일진은 커녕 같은 찐따 눈도 못마주쳤는데 이제는 배달음식 주문할때도 큰 소리로 또박또박말하고 편의점 피시방에서도 알바생이랑 눈마주치기 가능해졋다 아무리 기분 나쁜 거 같은 일이 생', '오픈크리틱 점', '개 좆같은 쓰레기년들아 실행은 하게해줘라 씨발 내돈주고 산건데 겜을 못하면 어쩌잔거냐', '언제 나오나요', '하얀화면에서 튕기기만해서 겜 자체를 못하는중', '말레니아 씨발년아', '그럴 자격 없다 오오 그럴 자격 없다', '컴퓨터에서 김포공항 소리남', '화면이 자꾸 꺼집니다 왜그럴까요', '무기 양손잡기 는 왼쪽 마우스 클릭 입니다', '보스 시발련아 좀 떄려봐 언제까지 들고만 있는데', '어리석은 야심은 잊고 환불하러 갑니다', '하얀화면 실행오류 어떻게 하는데 나도 엘든링 하고싶다고 슈밤', '혹시라도 나는 문제없이 잘 돌아가겠지 라고 생각하는 사람들 보세요 니 얘기야', '사양 충분히 맞췄는데 프레임 시발년들아', '최적화가 구리든 보스가 악랄하게 어렵든 가장 큰 문제는 초장부터 닼소류 처음하는 촉나라 유비들한테 남쪽 손권 사자 안치고 북쪽의 조조 멀키트 먼저 치라는 제작자놈들의 길 안내다 점성 렙찍누 동료 영체 고기방패로 어떻게든 잡았다', '스터터링 패치 되면 다시 살게', '게임이 안되잖아', '트리가드 이 씹련하고 투닥거리다 환불타이밍 놓쳤네 걍 한다', '개같이 멸망', '진짜 너무재밌는데 내가 중옵따리로 할라고 산건 아닌데', '손가락 하지만 구멍 오오 그럴자격 없다', '점프 눌렀다고 개새끼야', '울트라와이드를 지원 안한다고 왜 중소기업이라 그런가', '키세팅너무불편함', '본인사양 패치후에 원할하게 프레임 가능', '싯팔 실행이 안되서 평가고 나발도 못하겟네', '오니교부 트리가드로 개명하고 나왔더니 개쎄네', '오류 해결 방법 제어판 국가 또는 지역 관리자 옵션 시스템 로캘 변경 세계 언어 지원을 위해 사용 체크 일해라 프롬놈들', '엿같은 팅김 좀 어떻게 해바라', '잼씀 근데 사지마셈 할인하면 사셈', '이지 안티 치트 적당히 해야지 실행조차 안시켜주네 개같은 겜', '안티치트 씨발년들아', '한대만', '오오 그럴자격없다 오오 그럴자격없다', '라단 잡다가 모니터 뿌숨', '죽어도 다시한번', '전나맵네', '프레임빼면 맛있네요', '난이도 미쳤네 그냥 포르자 살걸 그랬다', '이게 년 게임', '내가 오늘 이 씹새낀 잡고 끈다 아', '재밌는거 같을라고 할때 딱 렉 걸림 이게 뭡니까 왜 맨날 기다린 사람이 손해봐야함', '슬슬 갓겜같으면 개추', '뭐지 이 오류덩어리는', '프레임 드랍도 일종의 패턴인가요', '프레임이 뚝뚝 끊겨서 진행을 못하겠어요', '꿀팁 외모 대충 설정해도 나중에 다시 변경 가능', '평가는 왜 닫았냐 돌았냐', '최적화나 되었으면', '나만 당할수 없지', '이 너머 구멍있다 그러니까 손가락 있으라', '림그레이브 이곳이 현생이다', '개미는 좀 너무한거 아니냐', '느낀다면 벽 싸워라 나자신 하지마라 욕 오오 그럴자격없다 오오 그럴자격없다', '나만 잘 돌아가냐', '금요일 퇴근시점에 파트내에서 급 저녁식사 해산물 먹는다고 하길래 갈팡질팡했지만 깔끔하게 집으로 컴백 그리고 엘든링 접속 플레이 환경 키보드 플레이 옵션 설정 시스템 상단 세번째 아이콘 클릭 설정 기본 디폴트값 시스템 상단 세번째 아이콘 클릭 조작 가이드 대상 기기 키보드 마우스 설정 키보드로 플레이가 가능하나 패드가 있으면 패드 권장합니다 느낌이 많이 다릅니다 사인 꿀팁 일일히 사인하는 자들을 위한 기본 가이드 아이템 작은 금 우상 사용 시 길 뚫어놓은', '한참 하는중', '흉조개씨발년아', '멀기트 씨발새끼', '날 정말 가지고 노는건지 잘 모르겟지만 개같다는건 확실하다 이겜을 사는 분들 절대적으로 개 부조리함의 끝을 맛보고 싶으시다면 추천 일단 난 변태가 아닌가봄 난 아님', '똥컴 쳐내', '인칭이 어지러운건 처음이다 에효', '이 앞 점프 유효하다', '트리가드 개새끼야', '이런 갓겜을 으로 즐기게 해준 사이버펑크 에게 이 영광을 돌린다', '프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임드랍 프레임', '장점 프롬 단점 프롬', '트 리 가 드 아', '최적화좀 신경썼으면', '쌍 도가니 기획하신분 주소좀 알려주세요 팬입니다 선물보내드리고 싶어요', '최적화 문제만 고치면 학실한 갓겜이다 그런데 메타크리틱 점짜리는 절대 아님', '최적화 이슈가 생각보다 없네요', '출시첫날 트리가드 진짜 미친거 아니냐 아니 돌았나 이게 보스냐 출시한지 일 후 이제 트리가드는 동네 똥개가 되었습니다', '다시만난 유다히 뭔가 반갑고 다시보기 싫다', '튜토리얼부터 버벅이냐 개적화 울트라와이드도 지원 안할거면서 는 왜 출시함 이게 왜 높은점수인지 모르겠다', '화면 끊김에 짜증나서 환불했습니다', '최적화만 완료된다면 최고의 갓겜이 될 것 같아요 중간중간에 아직 끊기는 현상이 있으시니 해결된 후에 구매하시는 거 추천드립니다', '마술사는 신이야 마술사는 신이야 마술사는 신이야 마술사는 신이야 마술사는 신이야', '최적화는 잘하고 내자', '매직링 저처럼 근접캐 키워서 생고생하지마시고 마법사를 키우세요 마법 못 쓰는 머글들은 사람취급 못 받고 개처럼 뚜까 쳐맞습니다 흑흑', '화신의 물방울 얻는 순간부터 아동 게임 댐', '다른건 몰라도 울트라와이드 지원좀', '프레임 뭐하고 있는거야 발 잼있다', '점만점 일색에 혹해서 샀는데 환불하고 세일하면 다시사야겠음', '발 튕겨서 시간 플레이 날렸다', '샤발럼의 안티치트', '그럴 자격 없다 오오 그럴 자격 없다 그러니까 그럴 자격 없다 오오 그럴 자격 없다', '시간이 모자라 휴가를써야하나', '미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸 깬다고 미야자키가 이걸', '버전은 아직 미완성인듯', '하지마십쇼 무슨 계속 튕기냐 이거 무슨 사펑도 아니고', '아니 진짜 첨부터 왜그러는걸까 이걸 하 왜 하냐 진짜 좀만 하고 꺼야지', '렉 너무 심함', '오픈월드에서 펼쳐지는 유다희와 연애시뮬레이션 이 곳에 구멍 하지만 손가락', '권장 사양 넘어선 훨씬 좋은 사양으로 프레임 에 프리징 씨발롬들아', '좋은 의미로 할게 너무 많음 프롬소프트 도 내줘', '와 컴퓨터 재부팅 프로그램', '스터터링 고쳐라 굴다리 밑에 집합하기 전까지 주 시간 준다 형의 인내심은 딱 주까지다 고치면 평가 긍정으로 돌린다 ...
#
# Cluster 2 (725)
# ['갓겜', '이 앞 좆같음 있다', '시발', '이것이야 말로 갓겜이다', '태양 어딨음', '사', '병신겜', '병신겜', '진짜 개적화겜', '이 앞', '굿', '헤헤 잼맸다', '갓 겜', '갓띵작', '씨발', '최적화좀', '갓겜', '갓겜', '피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖', '그냥 해', '피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖아피했잖', '갓겜', '망겜 수준', '굳', '아 진짜 씨발겜', '시발겜', '갓갓겜', '최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화좀해줘최적화', '갓겜', '굳', '의 시작이다', '하하', '정말 감사합니다', '갓겜', '닼소임', '최적화좀', '신', '어 갓겜', '해봐', '어렵네', '그저 씹갓겜', '그저빛', '좋다', '갓겜', '신', '야겜임', '갓겜', '갓겜', '최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀최적화좀', '씨발', '사', '시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데시발그래서길이어딘데', '그냥 갓겜 맞음', '갓겜', '그지같내', '병신겜', '좆 같 은 게 임', '그냥 닼소', '최적화', '잼', '망겜', '섹스', '최고', '굿', '갓겜', '마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존나쌔노마법존', '해봐라', '일단', '갓겜', '이게', '멅티안댐', '븅신 프리징겜', '갓겜', '태양 만세', '톤', '망겜', '로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에르사랑해로지에', '이 앞 갓겜 유효', '킹황갓겜', '최고다', '개똥겜', '갓겜', '굿', '힐링겜', '걍 갓겜', '최고', '인생겜', '굿', '질병', '예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가하지마예언가', '갓겜', '수준', '갓겜', '따봉', '발', '굿', '갓겜', '좆병신겜', '만점', '그래픽 망', '진짜 병신겜', '갓겜', '갓겜', '구웃', '잼', '갓 겜', '맵다', '갓겜', '굿', '갓겜', '국국', '최고', '굿', '갓겜 그 자체', '탈모획득쌉가능', '같은겜', '대작', '아아아아아아아앙', '갓겜', '때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까때릴까말까', '갓겜', '갓겜임', '갓겜', '갓겜', '갓겜', '좸뮛똬', '최고다', '갓겜', '킹아', '한번 잡숴보쉴', '그냥굿', '갓겜', '갓겜', '굳', '갓겜', '따봉', '줘', '그저 갓겜', '최고', '굿겜', '대박', '굿굿', '굿', '그저 빛', '미 친 갓 겜', '굿', '살려줘', '갓갓갓', '손가락 만세', '우선 열심히 해라', '갓겜', '갓겜', '어 어어엇 박', '체고야', '엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링섹엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링스엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘든링엘', '갓겜', '라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라니라', '갓 겜', '우주갓겜', '갓겜', '개똥갓겜', '초갓겜', '갓겜', '갓겜', '굳', '정신나가', '갓 겜', '갓겜', '그저 최고', '갓겜', '굿', '갓겜', '인생', '갓겜 그자체', '갓겜', '정말 갓겜입니다', '마법 만세', '굳', '굳', '앙 앙 앙 히릿', '잼', '야스', '갓겜', '최초 최고갓겜', '인생 갓겜', '귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한것을보게되리라귀공은끔찍한 ...
#
# Cluster 3 (3296)
# ['장점은 갓겜 단점은 개적화 제어판에서 쉐이더 캐쉬 무제한 설정 관리 프로그램 설정 엘든링 추가 전원 관리 모드를 최고 성능 선호 카메라 조작중 스터터링 증상 모두 사라짐', '엘든 링 시간을 하고 느낀 소감입니다 최적화에 대한 말들이 엄청나게 심한데 이것은 확실한 프롬 소프트웨어의 잘못입니다 최소사양이 에 권장사양이 인 탓에 여러 유저들의 사이에서도 최적화가 이상한 것 아니냐 아니면 그래픽이 황홀해서 그런 것이냐 이런 말들이 나왔었는데 막상 나온 후 뚜껑을 열어보니 세키로와 다크소울 에서 보여준 퍼포먼스에서 약간 상향된 그래픽 수준에 개떡같은 최적화인 것을 알 수 있었습니다 심지어 보스를 잡을 때도 프레임드랍과 스타터링이 생', '스타터링 최적화 이슈로 오너 조차 빡친거 보고 패치되면 나도 돌릴 수 있겠지 싶은 십똥컴들 개추', '바닥에 글씨 쓰는 재미를 준 게임', '요즘 게임 불감증 이었는데 오랜만에 진짜 재밌게한거 같음', '무기 양잡 꾹 누르기 마우스 좌 우클릭 장비창 장착해제 맵 열기 맵 조작 텔포 선택 전작과 달리 탈리스만은 신앙 매개가 아닌 패시브 부적 느낌 얻는 즉시 착용할 것 전작의 소울 화폐 룬 방패로 공격 막고 공격 가하면 일명 가드 카운터 라는 추가 데미지 입힘 이상 쌍타도로 고드릭까지 혼내준 엘린이 주저리였음', '스케일이 매우매우 크다 친구들과 진행 상황을 공유하는데 서로 다른 게임을 하는 것 같은 생각이 들 정도로 사람에 따라 자유도와 진행 순서가 천차만별이다 그만큼 초회차때는 탐험하고 던전을 찾는 재미가 쏠쏠하다 다크 소울 시리즈를 해보고 평타만 남발해서 적을 죽이는 버릇이 들었다면 꽤 힘들 것이다 엘든 링에서는 전회 강공격 점프공격의 데미지와 효율이 소울 시리즈보다 월등히 좋아졌다 이러한 기술들과 마상 전투 등의 시스템을 적절히 섞어 쓰면 난이도가 내려가는', '게임하기 조아하던 아줌마입니다 어제 하루종일 해봤는데 트리가드한테도 뚜들겨맞고 멀기트도 못잡겠구 길가다가도 뒤져버리구 이게 실력이 부족해선지 자꾸 미세하게 끊겨서 그런건지 인생에 현타가 오네용 임신했을때 다크서울은 어떻게 다깼던건지 꿈이었나봐요 이 아줌마는 그냥 겜접구 애기나 봐야겠어유', '매우 재밌음 진짜 얼마만에 이렇게 미친듯이 겜하는지 모르겠음 엔비디아 제어판 수직동기 빠르게 설정하고 하세요 최적화문제 있다고 하지만 와 둘다 구매해서 플레이해봤지만 사양이 괜찮다면 가 더 낫습니다 이하로 잘 안떨어짐 가끔 드랍구간 있긴하지만요', '시간 플레이하며 도전과제 달성 후 작성해보는 후기 오랜만에 이만큼 몰입하며 즐겨본 적이 언제였나 싶을 정도로 재밌게 했습니다 프롬식 간접적 스토리텔링 방식이 환상적인 아트웍과 어우러지며 상상력을 자극하네요 다만 중후반부의 레벨 디자인이나 보스 디자인에 있어서는 좀 짜증이 많이 났습니다 우선 단점으로 꼽자면 불합리한 보스 디자인이 생각외로 매우 많습니다 적사자성에서 등장하는 도가니 혼종 듀오나 신의 살갗 듀오는 영체 없이 잡기에는 스트레스만 오지게 쌓이고', '공략을 보지말라고 말씀드리고 싶네요 모르는 세계를 모르는 대로 자유롭게 여행하세요 당신의 목적을 이루기 위해 약한 당신은 세계의 비밀을 파해쳐야합니다 그렇게 흘러가다가 운명을 만나실겁니다 그렇게 즐기면 참 재밌습니다 탐험하세요 미지의 세계를', '엘든 링 세시간 플레이 후기 최적화 현재 가장 뜨겁게 논란이 되고 있는 화두인 최적화는 긴급한 패치가 필요한 수준 이라고 생각합니다 게임이 실행되지 않거나 크래시가 발생하는 현상 등을 겪어보지는 못했지만 프레임 드랍과 자잘한 끊김은 크게 심각하다고 느꼈는데요 를 누르면 일시 정지를 할 수 있는 게임도 아니다보니 계속되는 프레임 드랍은 스트레스를 유발했으며 설정을 건드리면 막을 수 있을지라도 발매 직후인 현재 게이머들이 공통적으로 손쉽게 대응할 수 있는', '맵이 넓습니다 할게 많다는뜻이죠 반대로 저같은 길치는 겜 내내 좃 같다는 뜻입니다 하지만 좃 같음을 넘어선 재미가 있습니다 정가로 샀지만 후회없구요 하지만 몇몇 보스가 뒤지게 꼬울수는 있습니다 당신이 똥고집을 부려서 나는 영체도 필요없고 마법도 필요없는 새끼다 하고 고집을 부리면 안 그래도 좃같던 게임이 개좃이 되는 경험을 하실수있습니다 로망도 좋지만 나는 혼자 싸우는데 적은 둘이 덤비는 상태에선 친구를 부르는것도 역시 공평한게 아닐까요 빛 바랜자 화이', '권모술수라는 말이 있습니다 우리가 원하는 목적을 이루기 위해서는 다른 건 신경쓰지 말고 모든 수단과 방법을 동원하여 이루라는 뜻이라고 합니다 이 말이 왜 이 게임과 관련되어 있냐고 물으신다면 해석의 여지는 항상 열려있지만 저는 이 게임을 오픈월드로 만든 프롬의 목적과 연관된다고 생각합니다 한때 우리는 멀기트에 발이 묶여있던 적이 있었습니다 그 때 여러분들은 어떻게 멀기트를 잡았을까요 근접무기로 패버리는 플레이로 잡았든 당시 최고의 주문인 휘석 돌팔매로', '일날 퇴사 일날 아침부터 매일매일 하루 시간씩만 자면서 망자짓한 보람이 있다 트레일러 음악만 안들었어도 그 미친 관악기 세션만 거기서 틀어주지 않았더라도 프롬 특유의 어두운 서사뿐만 아니라 야망이 기다리고 있을 거라는 기대감이 불타오르지는 않았을 텐데 음악을 들은 시점에서 마음은 아무래도 림그레이브에 가있던 모양이다 다크 소울 의 막보스는 말할 필요도 없고 의 막보스는 그 모든 설정 음악 무브셋에 담긴 모든 의미에 감사하며 싸웠었다 특히나 고리의 도시', '버벅거림이 있긴 해도 즐길점은 많은 게임 다만 아직은 다른 사람한테 해보라고 추천할 정도는 아닌듯', '오랬동안 기다려온 엘든링 엔딩까지 달리면서 하루종일 생각날 정도로 재미있게 플레이했다 하지만 그와 별개로 아쉬운점도 많았다 먼저 엘든링의 장점부터 살펴보자면 다크소울을 계승하는 완성도높은 시스템과 전투액션 특히 엘든링에서는 전회의 수가 전작들과 비교할수도 없이 많아지고 화려해졌다 그리고 커스터 마이징까지 가능해지면서 색다른 재미를 준다 이번작에서는 또한 점프액션이 추가되었는데 이로 인해서 플랫포머 형식의 디자인이 많아져 깨알같은 재미를 더한다 오픈월드를', '최적화 이슈는 제외하고 게임 재미로만 평가한다면 씹갓겜 기존 소울류 팬들한테는 초갓겜이지만 기존에 소울 시리즈를 싫어하시는 분들은 구매 안하시는거 추천합니다', '회차로 캐릭터를 돌리고 도전과제 퍼 채우고 리뷰씀 난이도 말이 많았는데 노영체 해보면 느끼겠지만 난이도 자체가 엇박에 광역기에 트릭까지 넣는 놈도 있어서 엄청 높았음 특히 근캐할때 토 나올정도로 근데 시간지나면서 여러 전회들이 발굴되고 특히 사냥개의 스탭이란 전회를 쓰면서 전작이랑 비슷하거나 쉬울정도로 난이도가 내려가더라 게임자체가 시스템을 활용하라고 보스들을 만들어 놨다고 생각함 시스템을 안쓰고 전작처럼 구르기 평타만 하기엔 버거울 정도였음 프롬이 밀', '게임 자체는 초반은 괜찮은 편인데 프레임 드랍이랑 스터터링 때문에 플레이 경험이 별로 안 좋습니다 급하지 않은 분들은 패치 좀 되고 게임 전체 밸런스가 괜찮아지면 구매하시는 걸 추천 드립니다', '여러분 만약에 어쩌다가 저어 기 짐승신전 오시게 되시면 흑드라군이 하나 뒤돌아 서있을텐데 엥간하면 건들지마요 트리가드놈이랑 달리 여러분을 원큐에 축복으로 발사 해줍니다 물론 소환수 늑대도 한방에 다들 퇴근들 해버리시니 참고 바닥에 보면 원거리로 공략하라는 말이 있는데 법사는 모르겠지만 일반캐로 그러면 모래알갱이 던지는 데미지 볼수있고 또한 내부라고 안심하고 개기다가 사자후 두방맞고 축복으로 돌아가는 신비로움도 겪게되니까 알아둬용', '소울류 그닥 좋아하지는 않는데 요놈은 물건임 맵도 크고 아름다워서 탐험하는 재미가 쏠쏠함 캐릭터 육성 개꿀잼 그리고 죽어가면서 보스 패턴 익히고 조졌을때 그 희열감이란 장난아님 프롬식 오픈월드 소울게임 나중에 또 나오거나 나오면 무조건 산다', '플레이 환경 해상도 그래픽 설정 높음 그래픽 년에 출시된 게임이라고는 믿기지 않는 기존 소울 류 그래픽을 그대로 계승 하였습니다 물론 이 부분은 게임성을 고려하면 상대적으로 중요하지는 않기에 넘어가겠습니다 최적화 및 설정 여타 게임들에 비해서 연출 대비 최적화 부문에서는 굉장히 미흡 합니다 옵션을 타협하지 않았다고는 하지만 고사양 기준으로도 프레임이 유지 ...
#
# Cluster 4 (1075)
# ['존나재밌네뒤질래', '어려워서 재미있네요', '재밌어용', '좇노잼', '어드벤처 나이스', '재미는 있음 근데 이제 존나 어려운', '개꿀잼', '재밌음', '재밌네', '너무 잼나', '리얼굿잼', '욕하면서 재밌게 함', '준네 잼있다', '왜이렇게 재미진거야', '재미있어요 쉬워요', '잼슴', '좀 해봤는데 재밌네요', '조금만 해봤는데 가볍게 하기 좋고 재밌어요', '맛있는 매운 맛', '그냥 재밌다', '나는 존나 재밌다', '개쉽고 재미있음', '대존잼', '즐길거리 더 많은 닼소 그래서 더 좋다', '아직 많이 못했는데 재미있네요', '재밌긴 한데 힘들다', '아주좋소', '타격감 굿', '재밌습니다', '재밌네', '재밌는데 화남', '존나 재밌다', '와 재밌다', '존나재밋음', '게임 존나 재밌네', '너무 재밌다', '너무 재미씀', '역시 존잼', '꿀잼', '최적환지 뭔지 모르겠고 그냥 개재밌다', '개잼씀', '재밌음', '어렵지만 재밌음', '재밌다 이게 풀프라이스지', '꾸르잼', '재밌다 역시 프롬', '개꿀잼 내 취향 저격임 님들아 이거 사서 얼른 해봐야지 알음', '매운데 맛있는데 매워', '이건 정말 말도안되게 재미있다 어떻게 이런게임을 준비한거지 정말 대단하다', '별로 재밌네요', '재밌게 하고있음', '와 진짜 재밌다', '짱짱재밋다맨이야', '존나재밌음', '넘모 재미따', '잼잇슴', '예 뭐 그냥 재밌어요', '같은데 같이 잼씀', '긴말 안 하겠습니다 걍 존나 재밌습니다', '조금밖에 안 해봤는데 재밌네요', '매우 재미 있음', '진짜 너네가 최고다', '재미가 있습니다', '재밌다', '개시발 좆같이 잘만들었네', '예스잼', '트리가드 스킵하면 재밌음', '재밌당', '재미있음', '오랫만에 설렌다', '아 이것이 행복', '재밌음', '즐겁다', '재밌음', '그 난 존나 재밌는데 개추', '최적화 이슈가 있긴한대 그냥 존나 재밌다', '꿀잼', '개꿀잼 닼소 보다 몇십배는 재밌음', '아주 재밌어버리고', '재미있다', '몰입감이 최고임', '출시하고 조금 해봤는데 재밌네요', '재밌어서 현생에 지장이 오네요', '개재밌다', '매우 재밌는 게임', '재밌어요', '렉은 잘 모르겠고 조오오온나 재밌는데', '재밌다', '뭐 말이 필요있나 그냥 재미있어', '인생 최고 갓겜', '쉬워서 너무 재미있어요', '누가 뭐라해도 정신없이 겜할정도로 재밌다', '개노잼', '게임은 재밌어', '슬슬 재밌음', '너무 재미있습니다', '걍 잼슴 하샘', '할수록 재미짐', '정말 재미있고 우리 아이가 좋아해요', '개재밋음', '재밌는데 너무 어렵다', '잘만되고 재미만 있구만', '존나 재미있따', '참 훌륭한 최적화에 감탄하고 갑니다', '너무재밌당', '진짜 난 너무 재밌는뎅', '그냥 미뗬음 존잼', '멀미나도 재미있다', '재미있는 똥겜이 이런거 아닐까', '미친듯이 어렵다 근데 그만큼 재밌다', '존나 재밌는데 비추는 뭐임 난 잘돌아가는데', '재미있슴', '재밌어요', '졸라 재미슴', '소울류 입문인데 개꿀잼 으로 잘돌아감', '탐험만 해도 재밌음', '그래픽 진짜 예뻐', '재미없다', '좆망겜인데 재밌음', '재밌습니다', '재밌음', '재미는 상당했다', '잠깐했는데 재밌네요', '어쩔티비 저쩔티비 나는 재밌게 하고 있어', '난 게임 잘 돌아간다 개재밌다 닼소팬이라면 강추', '와 이거 진짜 생각보다는 쉬운데요 특히 번째 팔 많은 보스는 진짜 귀여움 다들 도전 꼭 해보시길 바랍니다 너무 재밌어요', '재미있어요', '나만재밌는거임', '아 난 재밌다고', '개재밌노 이기', '너무 쉽네요', '맵다매워', '재미있는데 보지빨고싶 가', '꿀잼', '잘했다', '재밌다', '너무 재밌다', '친구와 하면 더 재미남', '재미따', '재밌다', '존 나 재밌음', '꿀잼', '맛있게 맵다', '개꿀잼', '그냥 재밌다', '최고 재밌음', '너무 재밌음', '존나 재밌네 쓰레기겜', '제밌다', '그래 이 맛이야', '존나 재밌다', '재밌어영', '완성도가 높음', '꿀잼이네요', '재밋어요', '재밌어요', '난 재밌음 계속하는 중', '꿀잼', '재밌음', '조금 해봤는데 재밌네요', '좋아요 이런류는 처음이지만 쉬워서 더 좋은거 같아요', '매운데 맛있어요', '존잼 시간가는줄모름 스케일도 방대함', '으허허헣 허 잼미따', '구경하기만해도재밌음', '재밌어요', '개꿀잼', '행복한 고통이다', '개꿀잼', '재밌음', '개꿀잼', '개꿀잼', '재미는있는데 어렵다', '재밌다', '그냥 존나 재밌다 이게 게임이지', '잼있네', '너무너무 재밌어요', '멋과 맛이 적절한 콤보', '꿀잼 근대 난 구더기', '조금밖에 안했지만 너무 뉴비 친화적이고 재미있네요', '갸 꿀잼', '재밌습니다', '끝내주는 긴장감 최고입니다', '재밌당', '변태라면 추천한다 개꿀잼', '회차가 끝난 지금도 설레이고 너무 재밌다', '헤으응 너무 재밋어', '재미짐', '히히 재밌다', '초반만 버티면 넘나 재미써', '조옹나 개 꿀잼', '존잼', '말이 필요한가 그저 재밌다', '문제점이 없는건 아닐텐데 그냥 너무 재밌다 진짜 그냥 너무 재밌음', '정말 재밌게 했고 하고 있음', '그냥 재밌다', '재미있다', '재밌어어요 시간많을때 하세요', '재미 보장 갓 뵤옹신 겜', '소울류 입문하기에 갱장히 재밌음', '재미지다', '소울 첨 해보는데도 개꿀잼', '졸잼', '이 너머 행복 있다', '아 너무 재밌다', '아 개재밌네', '그냥 최고다', '스토리복구 너무 조쿠요', '꿀잼', '재밌음', '좆같아서 재밌음', '흠 어허 오호 오 헐 우와씨', '소울류 첨해보는데 잼남', '씹존잼', '맛있게 맵다', '콘텐츠가 풍부해요', '재밌어요', '하루 종일 이것만 하고 싶을만큼 재밌네요', '존나 쉽네', '교수님들과 즐거운 강의', '열받아요 재밌어요', '무조건 재미있다', '단점 프레임드랍 장점 재밌다', '개인적으로 너무 재미있게 즐겼습니다 회차에 업적 다하고 끝낼려구요', '조금밖에 안 했는데 재밌네요', '어려워서 짜증나는데 재밌음 잘만듬 완벽도 최고', '진존잼', '재밌음', '일단 재밌음', '재밌음 오픈월드 짱', '너무 재밌어요 트리가드 개새끼야', '그럭저럭 재밌어요', '아직 얼마 안해봤지만 재미있음 컨텐츠가 너무 많아요', '재미있었다', '역시 이 맛을 잊을 수가 없어요', '재미있네요', '개꿀잼', '재밌음', '재밌는데 빡침', '꿀잼 개꿀잼 돈이 한개도 안아깝다', '재밋는데 개빡침', '맛있는 똥맛', '그냥 빠져듦 너무 재밌다', '어쨋든 게임은 재밌다', '재밌음', '재밌음', '재밋당', '개꿀잼', '재밌음', '재밌음', '재미있네요', '아직 별로 안해서그런지 잘모르겠는데 정말 재밌는거같아요', '꿀잼', '재밌네요', '응 쥰내 재밌어', '재밌음 야발', '재미다', '잼있어용', '존 잼', '어렵지만 잼있다', '재밌네요', '재밌음', '재미땅', '재밌다 어렵다', '그저 재밌음', '잼씀', '잼있네잉', '재미짐', '죤나 재밌군', '걍 존나 재밌다', '너무너무 재미있다', '재미있음 돈값함', '재미쩡', '재밌네요', '너무 재밋게하고 있음', '할만하넹', '즐겁다 미리 깐 마법 마참내', '아쉬운것도 많은대 그래도 재밌게 함', '재미남 팔병신인데도 학원까지깸', '좋음', '넘잼써여', '진짜 재미난다', '재밌다 너무행복한게임', '아 즐겁다', '꿀잼', '일단 초반인대 재미있당', '존 나재밌음', '이 너머 굉장히 멋진 게임', '맵단짠 그자체', '이 너머 재미 있다 그러니까 아마도 띵겜', '재밌긴해 근데 추천은 안한다', '매순간이 짜릿하고 재밌다 웃긴상황도 많고 즐거움', '와 재밌다', '재밌어요', '개재밌음', '이 앞 재미 있다', '너무 재밌음 근데 어려움', '재미있다', '너무 재밌어요 초반만 버티면 개꿀잼', '재밋따', '소울겜으로하기에는 너무 어렵지만 그냥 액션겜으로 하기엔 재미있다', '재밌어요', '어렵지만 랩업하면 재미남', '조금 해봤는데 재밌 ...
#
# Cluster 5 (375)
# ['엘든 링인 것 같지', '엘든링 최적화좀', '아직 엘든링 안나옴 더기다리셈', '이 너머 기쁨 있다 즉 엘든 링 오오 엘든 링', '나는 엘데의 진정한 왕이다', '다크소울 잖아요 이게 왜 마스터피스', '시발 날 엘든링 속으로 보내줘', '이 앞 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 있다 따라서 갓겜 있음', '보크를 엘데의 왕으로', '오오오 스터터 링 스터터 링 엘든 링', '아이 엠 말레니아 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이드 오브 미켈라 아이 엠 말레이나 블레이', '엘든링 만세', '잠시나마 행복했습니다 고대 그리스 무사의 삶 또는 소크라테스 또는 플라톤의 삶 저는 누구였을까요 누구에게는 마법사 또 누군가에게는 검사 훗 많은 것을 저에게 알려준 이 엘든링 누군가에게는 갓든링 누군가에게는 근든링 누군가에게는 좆든링 하지만 저에게 많은것을 알려준 엘든링 수고많았다 쏴라 아 아름답다 쩦 축복에서 쉰다 영원히', '아 엘더 왕 그게 뭐냐고 메인 퀘스트 관심없다고 말 타고 놀러다닐 거라고', '프롬겜 좋아하신다면 무조건 추천드립니다 닼소 에선 설리번에 막혀서 접었는데 엘든링은 더 족같은애들이 많은데도 계속 하게 되네요', '이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘든링있다 이 앞 엘', '오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오 엘든링 오오', '뭐어 엘든링 엘든링', '엘든 링', '그저 갓겜이다 엘든링', '엘 든 링', '대 반지 스터터링 티어링 엘든링', '이건 엘든 링이야 프롬의 신작이지 와 다크 소울 이건 축복이야 이곳에서 재정비를 할 수 있어 와 화톳불 이건 룬이야 이 세계에서의 화폐라 보면 돼 와 소울 이건 전회라는거야 무기에 장착해서 쓸 수 있는 특별한 기술이지 와 전기', '이 앞에 엘든링있다', '오 엘든링 오', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '엘든링 할려고 코로나 걸렸습니다', '엘든 링 만세', '엘든링 때문에 다잉라이트 하다가 접었음', '아아 난 엘데의 왕 이다', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '너 다크소울 맞잖아 너', '엘든링이 잘돌아가는거보니 년정도 더 써도 될듯', '솔라는 어디 갔고 그윈은 어디 갔고 스모우와 온슈타인은 어디 갔고 아르토리우스는 어디 갔고 작은 론도는 어디 갔고 시프는 어디 갔고 로트렉은 어디 갔고 그윈돌린은 어디 갔고 루카티엘은 어디 갔고 백왕은 어디 갔고 게르만은 어디 갔고 인형은 어디 갔고 에일린은 어디 갔고 이오셰프카는 어디 갔고 개스코인은 어디 갔고 알프레드는 어디 갔고 아멜리아는 어디 갔고 루드비히는 어디 갔고 양파는 어디 갔고 국민들을 지키던 욤은 어디 갔고 화방녀는 어디 갔고 호크우드', '이 너머 엘든링 있음 그러므로 나는해냈다 의 시간이다', '뭐 엘든링 엘든링님이라고 불러라', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '한 시간 한 소감은 다크소울 스꼴라', '다크소울', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링 엘든 링', '엘든링 엘든링', '명작입니다 명작 프롬아 도착했어 고티 확정작이야 어쩌면 한국인 최초의 엘든링 리뷰일지도 모르는 리뷰', '엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링 엘든링', '엘든링 엔딩 바라볼지라 하지만 그럴 자격 없다 오오 그럴 자격 없다', '너네 엘든링 함부로 만지지마라 지인분 돌아가심 귀엽다면서 만지려고 하는데 다들 말리시더라 괜찮다면 ...

# %% [markdown]
# # 워드클라우드 그리기

# %% [markdown]
# ## 형태소 분석, 명사 추출

# %%
# !pip install -q konlpy tqdm
# Out:
#      |████████████████████████████████| 19.4 MB 8.1 MB/s
#      |████████████████████████████████| 465 kB 56.0 MB/s

# %%
from konlpy.tag import Komoran, Okt, Kkma, Hannanum
from tqdm import tqdm

extractor = Hannanum()

nouns = []

for review in tqdm(df['review'].values.tolist()):
    nouns.extend(extractor.nouns(review))

len(nouns)
# Out:
# 100%|██████████| 8242/8242 [00:57<00:00, 142.43it/s]
# 73548

# %%
from collections import Counter

count = Counter(nouns)
words = dict(count.most_common())

for i, (word, count) in enumerate(words.items()):
    if i > 10:
        break

    print(word, count)
# Out:
# 게임 2268
# 엘든링 2225
# 것 1038
# 수 807
# 소울 806
# 최적화 746
# 다크소울 659
# 나 569
# 갓겜 546
# 오픈월드 546
# 시간 521

# %% [markdown]
# ## 한글 폰트 다운로드

# %%
# !wget https://github.com/kairess/MBTI-wordcloud/raw/master/NanumSquareRoundR.ttf
# Out:
# --2022-12-15 02:53:36--  https://github.com/kairess/MBTI-wordcloud/raw/master/NanumSquareRoundR.ttf
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kairess/MBTI-wordcloud/master/NanumSquareRoundR.ttf [following]
# --2022-12-15 02:53:36--  https://raw.githubusercontent.com/kairess/MBTI-wordcloud/master/NanumSquareRoundR.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1063276 (1.0M) [application/octet-stream]
# Saving to: ‘NanumSquareRoundR.ttf’
#
# NanumSquareRoundR.t 100%[===================>]   1.01M  --.-KB/s    in 0.005s
#
# 2022-12-15 02:53:37 (203 MB/s) - ‘NanumSquareRoundR.ttf’ saved [1063276/1063276]

# %% [markdown]
# ## 워드클라우드 그리기

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(
    font_path='NanumSquareRoundR.ttf',
    width=2000,
    height=1000
).generate_from_frequencies(words)

plt.figure(figsize=(20, 10))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# # 기타

# %%
df['voted_up'].value_counts().plot(kind='bar', title='Voted Up')

# %%
import json

total_playtime = 0

for i in range(len(df)):
    playtime = json.loads(df.iloc[i]['author'].replace("\'", "\""))['playtime_forever']

    total_playtime += playtime

print('전체 플레이타임 합계 (분)', total_playtime)
print('전체 플레이타임 합계 (시간)', total_playtime / 60)
print('평균 플레이타임 (시간)', total_playtime / len(df) / 60)
# Out:
# 전체 플레이타임 합계 (분) 43254990
# 전체 플레이타임 합계 (시간) 720916.5
# 평균 플레이타임 (시간) 87.46863625333657

# %%
print('이 앞 엘든링 있다')
# Out:
# 빛바랜 자 화이팅!
